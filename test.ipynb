# %%
import pandas as pd
# Out:
# Running cells with 'DSA104test (Python 3.12.8)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/jschoer/Desktop/DSA104 development/DSA104test/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
